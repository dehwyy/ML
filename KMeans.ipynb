# %% [markdown]
# <a href="https://colab.research.google.com/github/dehwyy/ML/blob/master/KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()

iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

iris_scaled = scaler.fit_transform(iris_df)

iris_df_scaled = pd.DataFrame(iris_scaled, columns=iris.feature_names)

# %%
X = iris_df_scaled

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 42)

y_pred = kmeans.fit_predict(X)

for i in range(len(y_pred)):
  if y_pred[i] == 1:
    y_pred[i] = 0
  elif y_pred[i] == 0:
    y_pred[i] = 1

# %%
d = {"Target": iris.target, "Predict": y_pred}

df = pd.DataFrame(d, columns=d.keys())

import numpy as np

df["Comparisation"] = np.where(df["Target"] == df["Predict"], True, False)

df["Comparisation"].value_counts(normalize=True).round(3)
# Out:
# Comparisation
# True     0.833
# False    0.167
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,6))


plt.scatter(X.iloc[:,0], X.iloc[:,1], c = iris.target, cmap = 'Paired')

# %%
plt.figure(figsize = (10,6))

plt.scatter(X.iloc[:,0], X.iloc[:,1], c = y_pred, cmap='Paired')
